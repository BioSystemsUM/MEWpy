# %% [markdown]
# # MEWpy Simulation
#
# This notebook exemplifies how MEWpy may be used as an interface for COBRApy and REFRAMED.

# %% [markdown]
# Models can be loaded using REFRAMED:

# %%
from reframed.io.sbml import load_cbmodel
model = load_cbmodel('models/ec/iML1515.xml',flavor='cobra')

# %% [markdown]
# or using COBRApy:

# %%
from cobra.io import read_sbml_model
model = read_sbml_model('models/ec/iML1515.xml')

# %% [markdown]
# A simulator object provides a common interface to realize the main phenotype analysis tasks. The *get_simulator* function returns a simulator, a wrapper,  for the provided model. The simulator interface remains the same regardless of how the model was loaded, using REFRAMED or COBRApy. This simplify the use of both environments and ease the management of future changes and deprecation on their APIs.

# %%
from mewpy.simulation import get_simulator
simul = get_simulator(model)

# %% [markdown]
# The simulator offers a wide API, and enable to perform basic tasks, such as, list  metabolites, reactions, genes and compartments:

# %%
simul.metabolites[:10]
# Out:
# ['octapb_c',
#  'cysi__L_e',
#  'dhap_c',
#  'prbatp_c',
#  '10fthf_c',
#  'btal_c',
#  '6pgg_c',
#  'co2_e',
#  'akg_e',
#  'gsn_e']

# %%
simul.reactions[:10]
# Out:
# ['CYTDK2',
#  'XPPT',
#  'HXPRT',
#  'NDPK5',
#  'SHK3Dr',
#  'NDPK6',
#  'NDPK8',
#  'DHORTS',
#  'OMPDC',
#  'PYNP2r']

# %%
simul.genes[:10]
# Out:
# ['b2551',
#  'b0870',
#  'b3368',
#  'b2436',
#  'b0008',
#  'b3500',
#  'b2465',
#  'b0945',
#  'b4467',
#  'b3126']

# %%
simul.compartments
# Out:
# {'c': 'cytosol', 'e': 'extracellular space', 'p': 'periplasm'}

# %% [markdown]
# A simulator may also be loaded considering environmental conditions, that will be considered during phenotype simulations. In the next example, glucose consumption is limited to 10 mmol/gDW/h and the oxygen is unlimited.

# %%
envcond = {'EX_glc__D_e': (-10.0, 100000.0),
           'EX_o2_e':(-1000,1000)}

simul = get_simulator(model,envcond=envcond)

# %% [markdown]
# All phenotype simulations will consider the imposed environmental conditions, and as such they only need to be set once. Also, these conditions do not persistently alter the model, which can be reused with a different simulator instance.

# %% [markdown]
# ## Phenotype simulation
#
# Phenotype simulations are also run using the simulator instance using  the `simulate` method.

# %%
# FBA 
result = simul.simulate()
# or 
result = simul.simulate(method='FBA')

result
# Out:
# objective: 0.8769972144269748
# Status: OPTIMAL

# %% [markdown]
# Flux Balance Analysis (FBA) can be run without identifying any method, or  by passing the 'FBA' as method parameter. Other phenotype simulation methods may also be run using one of the identifiers:
#
# - Flux Balance Analysis: `method = 'FBA'`
# - Parsimonious FBA:`method = 'pFBA'`
# - Minimization of Metabolic Adjustment:`method = 'MOMA'`
# - Linear MOMA: `method = 'lMOMA'`
# - Regulatory on/off minimization of metabolic flux: `method = 'ROOM'`

# %%
# pFBA
result = simul.simulate(method = 'pFBA')

result
# Out:
# objective: 769.7902399146501
# Status: OPTIMAL

# %% [markdown]
# ## Reaction fluxes
#
# The phenotype simulation result object, besides containing the objective value and solver status, also include reaction fluxes in the form of a dictionary:

# %%
result.fluxes
# Out:
# OrderedDict([('CYTDK2', 0.0),
#              ('XPPT', 0.0),
#              ('HXPRT', 0.0),
#              ('NDPK5', 0.0),
#              ('SHK3Dr', 0.33424030136519417),
#              ('NDPK6', 0.0),
#              ('NDPK8', 0.0),
#              ('DHORTS', -0.290106293546371),
#              ('OMPDC', 0.290106293546371),
#              ('PYNP2r', 0.0),
#              ('G5SD', 0.19386461923515486),
#              ('CS', 6.913003110880989),
#              ('ICDHyr', 6.913003110880989),
#              ('ALATA_L2', 0.0),
#              ('DURIPP', 0.0),
#              ('ACALD', 0.0),
#              ('PTRCTA', 0.0),
#              ('ACS', 0.0),
#              ('CYSDS', 0.0),
#              ('MAN6PI', 0.0),
#              ('PPA', 3.070860997140544),
#              ('APRAUR', 0.0003911407576345045),
#              ('TRPAS2', -0.049851152659672514),
#              ('PPCK', 0.0),
#              ('ME1', 0.0),
#              ('DB4PS', 0.000782281515269009),
#              ('ALAR', 0.036554997891745156),
#              ('RBFK', 0.0001955703788172892),
#              ('ALATA_L', -0.5102755672310485),
#              ('XYLK', 0.0),
#              ('RBK', 0.0),
#              ('GLYK', 0.0),
#              ('PPM', -0.0005902191253093526),
#              ('ASPTA', -2.567692615335191),
#              ('ACP1_FMN', 0.0),
#              ('RBFSb', 0.0003911407576345045),
#              ('NDP3', 0.0),
#              ('CDPPH', 0.0),
#              ('NDP7', 0.0),
#              ('FBP', 0.0),
#              ('EX_pi_e', -0.845956775019459),
#              ('GLGC', 0.0),
#              ('ALATA_D2', 0.0),
#              ('PYK', 0.0),
#              ('SHCHD2', 0.00019557037881721533),
#              ('EX_co2_e', 24.003293272975984),
#              ('A5PISO', 0.034125715607782436),
#              ('PMDPHT', 0.0003911407576345045),
#              ('CPPPGO', 0.00019557037881721533),
#              ('EX_met__L_e', 0.0),
#              ('GTHOr', 0.0),
#              ('ILETA', -0.2547931237102545),
#              ('DHORD5', 0.0),
#              ('EX_metsox_S__L_e', 0.0),
#              ('GLYCTO2', -5.246942214042945e-14),
#              ('VALTA', -0.37111189525134736),
#              ('GLYCTO3', 0.0),
#              ('IPPMIb', -0.3951144320129993),
#              ('GLYCTO4', 0.0),
#              ('ORPT', -0.290106293546371),
#              ('RBFSa', 0.000782281515269009),
#              ('ACHBS', 0.2547931237102545),
#              ('PFK_3', 0.6119224317254629),
#              ('DHAD2', 0.2547931237102545),
#              ('ACLS', 0.7668174233868702),
#              ('TRPS2', 0.0),
#              ('PSCVT', 0.33424030136519417),
#              ('G3PD5', 0.0),
#              ('G1PP', 0.0),
#              ('PFL', 0.0),
#              ('EX_acgam_e', 0.0),
#              ('ANS', 0.049851152659672514),
#              ('FRD2', 0.0),
#              ('FRD3', 0.0),
#              ('ANPRT', 0.049851152659672514),
#              ('POX', 0.0),
#              ('CHORM', 0.28360686719025274),
#              ('PTAr', -0.5105755002783823),
#              ('CHORS', 0.33424030136519417),
#              ('IGPS', 0.049851152659672514),
#              ('ACKr', 0.5105755002783823),
#              ('EX_cellb_e', 0.0),
#              ('EX_crn_e', 0.0),
#              ('EX_hxan_e', 0.0),
#              ('EX_ile__L_e', 0.0),
#              ('EX_chol_e', 0.0),
#              ('EX_fe3_e', 0.0),
#              ('LEUTAi', 0.3951144320129993),
#              ('EX_lac__L_e', 0.0),
#              ('EX_leu__L_e', 0.0),
#              ('EX_glcn_e', 0.0),
#              ('EX_no3_e', 0.0),
#              ('EX_h_e', 8.058200328043558),
#              ('DMATT', 0.00024380522561069849),
#              ('EX_orn_e', 0.0),
#              ('GRTT', 0.00024380522561069849),
#              ('EX_gln__L_e', 0.0),
#              ('UPP3S', 0.00039114075763443067),
#              ('EX_pro__L_e', 0.0),
#              ('EX_glyc_e', 0.0),
#              ('UPPDC1', 0.00019557037881721533),
#              ('EX_man_e', 0.0),
#              ('TMDPP', 0.0),
#              ('EX_ade_e', 0.0),
#              ('EX_mn2_e', -0.0006060050751690394),
#              ('EX_4abut_e', 0.0),
#              ('EX_ac_e', 0.0),
#              ('EX_akg_e', 0.0),
#              ('EX_ala__L_e', 0.0),
#              ('EX_arg__L_e', 0.0),
#              ('EX_asp__L_e', 0.0),
#              ('EX_pyr_e', 0.0),
#              ('EX_succ_e', 0.0),
#              ('EX_thymd_e', 0.0),
#              ('EX_rib__D_e', 0.0),
#              ('EX_tyr__L_e', 0.0),
#              ('EX_cytd_e', 0.0),
#              ('EX_dcyt_e', 0.0),
#              ('MOAT', 0.017062857803891218),
#              ('EX_fum_e', 0.0),
#              ('EX_sbt__D_e', 0.0),
#              ('EX_glu__L_e', 0.0),
#              ('UDCPDPS', 4.823484679348316e-05),
#              ('ECOAH6', 0.2438543374547068),
#              ('USHD', 0.017062857803891218),
#              ('EX_gua_e', 0.0),
#              ('ENO', 15.598897532203615),
#              ('FBA', 5.564027448338896),
#              ('HCO3E', 0.46097078383594603),
#              ('MGSA', 0.0),
#              ('IMPC', -0.47579905273747736),
#              ('IMPD', 0.21331027847064438),
#              ('PPS', 0.0),
#              ('ECOAH4', 0.3121057686702717),
#              ('LPADSS', 0.017062857803891218),
#              ('GLUTRS', 0.0031291260610754454),
#              ('TDSK', 0.017062857803891218),
#              ('PGI', 7.644633780205943),
#              ('TMPPP', 0.00019557037881721533),
#              ('EX_btn_e', 0.0),
#              ('PGK', -17.10543360355017),
#              ('EX_ptrc_e', 0.0),
#              ('EDA', 0.0),
#              ('EX_spmd_e', 0.0),
#              ('EX_thym_e', 0.0),
#              ('EX_xtsn_e', 0.0),
#              ('NTPP1', 0.0),
#              ('URIK1', 0.0),
#              ('URIK2', 0.0),
#              ('NTPP2', 0.0),
#              ('PGL', 2.3553662197940564),
#              ('NTPTP1', 0.0),
#              ('NTPTP2', 0.0),
#              ('CYTDK1', 0.0),
#              ('RPE', 0.8899957028434248),
#              ('DHQTi', 0.33424030136519417),
#              ('IPMD', 0.3951144320129993),
#              ('AIRC3', -0.3927140906370946),
#              ('TALA', 0.0),
#              ('PUNP1', -0.0005902191253093526),
#              ('PUNP2', 0.0),
#              ('PUNP3', 0.0),
#              ('ADSL2r', 0.3927140906370946),
#              ('TKT1', 0.6119224317254629),
#              ('EX_fe2_e', -0.014085452260911638),
#              ('PUNP5', 0.0),
#              ('PUNP6', 0.0),
#              ('PUNP7', 0.0),
#              ('G6PDA', 0.0),
#              ('RNDR1', 0.0),
#              ('ALCD2x', 0.0),
#              ('RNDR3', 0.0),
#              ('RNDR4', 0.0),
#              ('ALDD2y', 0.0),
#              ('TMDS', 0.022947509112696215),
#              ('RMI', 0.0),
#              ('TMDK1', 0.0),
#              ('LYSAM', 0.0),
#              ('PPCDC', 0.0005910961225234471),
#              ('FTHFD', 0.0),
#              ('EX_glc__D_e', -10.0),
#              ('DHAD1', 0.7668174233868702),
#              ('IPPMIa', -0.3951144320129993),
#              ('EX_alltn_e', 0.0),
#              ('G3PD7', 0.0),
#              ('EDD', 0.0),
#              ('EX_ura_e', 0.0),
#              ('NADH9', 0.0),
#              ('EX_val__L_e', 0.0),
#              ('NADH10', 0.0),
#              ('ADK4', 0.0),
#              ('INSK', 0.0),
#              ('MDH', 6.884588401133469),
#              ('ABTA', 0.0),
#              ('EX_xan_e', 0.0),
#              ('FUM', 6.884588401133521),
#              ('FMNAT', 0.0001955703788172892),
#              ('PYDXNK', 0.0),
#              ('PYAM5PO', 0.0),
#              ('SSALx', 0.0),
#              ('ASPT', 0.0),
#              ('OHPBAT', -0.00039114075768696346),
#              ('SERD_L', 0.0),
#              ('EX_dgsn_e', 0.0),
#              ('NADDP', 0.0),
#              ('EX_arab__L_e', 0.0),
#              ('EX_fru_e', 0.0),
#              ('THRD', 0.0),
#              ('HEX4', 0.0),
#              ('EX_gal_e', 0.0),
#              ('NMNAT', 0.0),
#              ('EX_xyl__D_e', 0.0),
#              ('KARA1', -0.7668174233868702),
#              ('HMPK1', 0.0),
#              ('KARA2', 0.2547931237102545),
#              ('EX_duri_e', 0.0),
#              ('EX_for_e', 0.0),
#              ('EX_gly_e', 0.0),
#              ('EX_h2_e', 0.0),
#              ('EX_lys__L_e', 0.0),
#              ('ACCOAC', 0.06825669319885144),
#              ('NADK', 0.0003920177548483489),
#              ('GLXCL', 0.0),
#              ('ICHORS_copy2', 0.0),
#              ('SUCBZS', 0.0),
#              ('DHBD', 0.0),
#              ('ICHORT', 0.0),
#              ('EX_ser__L_e', 0.0),
#              ('EX_thm_e', 0.0),
#              ('EX_trp__L_e', 0.0),
#              ('GLUTRR', 0.0031291260610754454),
#              ('GLCS1', 0.0),
#              ('GLCP', 0.0),
#              ('EX_din_e', 0.0),
#              ('RBK_L1', 0.0),
#              ('RBP4E', 0.0),
#              ('TARTD', 0.0),
#              ('NTD2', 0.0),
#              ('GLCRAL', 0.0),
#              ('NTD4', 0.0),
#              ('NTD5', 0.0),
#              ('EX_fmn_e', 0.0),
#              ('EX_gthox_e', 0.0),
#              ('KAS14', 0.0),
#              ('HEMEOS', 0.0),
#              ('ADMDC', 0.0),
#              ('AGMT', 0.0),
#              ('NTD6', 0.0),
#              ('LGTHL', 0.0),
#              ('PYDXPP', 0.0),
#              ('PDXPP', 0.0),
#              ('ARGDC', 0.0),
#              ('HACD6', 0.2438543374547068),
#              ('ECOAH1', 0.3121057686702717),
#              ('ECOAH2', 0.3121057686702717),
#              ('ARGSS', 0.25940876004978364),
#              ('AGPR', -0.25940876004978364),
#              ('SPMS', 0.0),
#              ('G1SAT', 0.0031291260610754454),
#              ('KDOCT2', 0.034125715607782436),
#              ('ECOAH3', 0.3121057686702717),
#              ('UGLT', 0.0),
#              ('EDTXS1', -7.648064842330726e-33),
#              ('DXPS', 0.0024862871029004683),
#              ('OAADC', 0.0),
#              ('MNNH', 0.0),
#              ('CDPMEK', 0.002095146345266037),
#              ('EDTXS2', -7.648064842330726e-33),
#              ('ALTRH', 0.0),
#              ('MECDPS', 0.002095146345266037),
#              ('GUI1', 0.0),
#              ('EDTXS3', 0.0),
#              ('PGAMT', -0.08286571279677597),
#              ('DDGLK', 0.0),
#              ('EDTXS4', 0.0),
#              ('XYLI2', 0.0),
#              ('PMANM', 0.0),
#              ('ICL', 0.0),
#              ('UAGDP', 0.08286571279677597),
#              ('UAGCVT', 0.024369998594496768),
#              ('GLUR', -0.024369998594496768),
#              ('EX_tmao_e', 0.0),
#              ('UAG2E', 0.0),
#              ('EX_acald_e', 0.0),
#              ('GLYCL', 0.047540703498227144),
#              ('CMPN', 0.0),
#              ('NNDPR', 0.0019977996544642603),
#              ('HCYSMT', 0.0),
#              ('EX_melib_e', 0.0),
#              ('MACPD', 0.0),
#              ('DMQMT', 0.0),
#              ('UDPG4E', 0.0),
#              ('LACZ', 0.0),
#              ('TRE6PH', 0.0),
#              ('XYLI1', 0.0),
#              ('PPC', 2.596107325082711),
#              ('ICHORS_copy1', 0.0),
#              ('EX_sucr_e', 0.0),
#              ('ALDD4', 0.0),
#              ('HACD4', 0.3121057686702717),
#              ('G3PT', 0.0),
#              ('CINNDO', 0.0),
#              ('DHPPD', 0.0),
#              ('EX_tre_e', 0.0),
#              ('EX_zn2_e', -0.0002990560501195983),
#              ('HACD5', 0.3121057686702717),
#              ('DHCIND', 0.0),
#              ('HACD7', 0.2438543374547068),
#              ('CITL', 0.0),
#              ('GOFUCR', 0.0),
#              ('PYDXK', 0.0),
#              ('DNMPPA', 0.0005867111364517094),
#              ('HPPK2', 0.0005867111364517094),
#              ('PTPATi', 0.0005910961225234471),
#              ('HEX7', 0.0),
#              ('DXPRIi', 0.002095146345266037),
#              ('GTPCII2', 0.0003911407576345045),
#              ('URIC', 0.0),
#              ('SADT2', 0.21704102462081615),
#              ('OPHBDC', 0.00019557037881721533),
#              ('AACPS1', 0.0),
#              ('OHPHM', 0.0),
#              ('GHMT2r', 0.9783188951027599),
#              ('DHORD2', 0.290106293546371),
#              ('LCARS', 0.0),
#              ('ALCD19', 0.0),
#              ('RMPA', 0.0),
#              ('SBTPD', 0.0),
#              ('PFK_2', 0.0),
#              ('GLTPD', 0.0),
#              ('EX_hdcea_e', 0.0),
#              ('ACACCT', 0.0),
#              ('SDPDS', 0.32532123969447174),
#              ('BUTCT', 0.0),
#              ('TGBPA', 0.0),
#              ('MANAO', 0.0),
#              ('TAGURr', 0.0),
#              ('DMSOR1', 0.0),
#              ('PGLYCP', 0.0),
#              ('2DGULRx', 0.0),
#              ('DKGLCNR2y', 0.0),
#              ('G1PTT', -7.648064842330726e-33),
#              ('TDPGDH', -7.648064842330726e-33),
#              ('ADCS', 0.0005867111364517094),
#              ('ADCL', 0.0005867111364517094),
#              ('2DGULRy', 0.0),
#              ('DHAPT', 2.2758138901882368),
#              ('EX_lac__D_e', 0.0),
#              ('UDPGALM', 0.0),
#              ('TDPDRE', -7.648064842330726e-33),
#              ('TDPDRR', -7.648064842330726e-33),
#              ('UMPK', 0.33153914994475897),
#              ('RZ5PP', 0.0),
#              ('DDPGALA', 0.0),
#              ('DURIK1', 0.0),
#              ('G3PD6', 0.0),
#              ('ALLTN', 0.0),
#              ('UAPGR', 0.024369998594496768),
#              ('UPPRT', 0.0),
#              ('NTD9', 0.0),
#              ('CTPS2', 0.14077997784589005),
#              ('NTD1', 0.0),
#              ('NTD7', 0.0),
#              ('PAPPT3', 0.024369998594496768),
#              ('UAGPT3', 0.024369998594496768),
#              ('NDPK7', 0.0),
#              ('AOBUTDs', 0.0),
#              ('GLYAT', 0.0),
#              ('ADNUC', 0.0),
#              ('GMHEPPA', 0.0),
#              ('S7PI', -3.0592259369322904e-32),
#              ('TRPS3', 0.049851152659672514),
#              ('EX_ttdcea_e', 0.0),
#              ('F6PA', 2.2758138901882368),
#              ('AGMHE', -3.0592259369322904e-32),
#              ('CRNBTCT', 0.0),
#              ('CRNCBCT', 0.0),
#              ('NTD10', 0.0),
#              ('CRNCDH', 0.0),
#              ('GMHEPAT', -3.0592259369322904e-32),
#              ('EX_h2s_e', 0.0),
#              ('ADPT', 0.0),
#              ('EX_gthrd_e', 0.0),
#              ('IDOND', 0.0),
#              ('IDOND2', 0.0),
#              ('FADRx', 1.917019441043779),
#              ('GTPDPK', 0.0),
#              ('NADN', 0.0),
#              ('GLYCLTDx', 0.0),
#              ('ADK1', 2.3007995610574903),
#              ('NDPK2', 0.372972006343147),
#              ('NDPK3', 0.15873912680292532),
#              ('HPYRRy', 0.0),
#              ('NDPK4', 0.022947509112696215),
#              ('ACODA', 0.25940876004978364),
#              ('ADA', 0.0),
#              ('DADA', 0.0),
#              ('ADD', 0.0),
#              ('FCLT', 0.00019557037881721533),
#              ('HBZOPT', 0.00019557037881721533),
#              ('PNTK', 0.0005910961225234471),
#              ('ADSS', 0.2624887742668329),
#              ('AGDC', 0.0),
#              ('OCTDPS', 0.00019557037881721533),
#              ('ASNN', 0.0),
#              ('DPCOAK', 0.0005910961225234471),
#              ('HETZK', 0.0),
#              ('ASNS2', 0.21140456352369433),
#              ('ASPCT', 0.290106293546371),
#              ('KDOPS', 0.034125715607782436),
#              ('KDOPP', 0.034125715607782436),
#              ('DMPPS', 0.00024380522561069849),
#              ('EX_26dap__M_e', 0.0),
#              ('MCOATA', 0.06825493920442258),
#              ('IPDPS', 0.0018513411196553386),
#              ('AST', 0.0),
#              ('SGDS', 0.0),
#              ('CYNTAH', 0.0),
#              ('DAPE', 0.32532123969447174),
#              ('DHDPRy', 0.32532123969447174),
#              ('EX_acnam_e', 0.0),
#              ('HSK', 0.4772759160465904),
#              ('SDPTA', -0.32532123969447174),
#              ('GSPMDA', 0.0),
#              ('GSPMDS', 0.0),
#              ('GUAD', 0.0),
#              ('THRS', 0.4772759160465904),
#              ('EX_amp_e', 0.0),
#              ('HSST', 0.13497951826967008),
#              ('PPNDH', 0.16247688893081344),
#              ('TMAOR1', 0.0),
#              ('TMAOR2', 0.0),
#              ('DGK1', 0.0),
#              ('DTMPK', 0.022947509112696215),
#              ('NDPK1', 0.6928400773582934),
#              ('TRDR', 0.21704102462081615),
#              ('DDPA', 0.33424030136519417),
#              ('NMNDA', 0.0),
#              ('NNAM', 0.0),
#              ('P5CD', 0.0),
#              ('PGMT', 0.0),
#              ('FRUK', 0.0),
#              ('SPMDAT1', 0.0),
#              ('RHCCE', 0.0003928947520632846),
#              ('EX_dha_e', 0.0),
#              ('KG6PDC', 0.0),
#              ('SPMDAT2', 0.0),
#              ('TDPADGAT', 0.0),
#              ('MALS', -5.246942214042945e-14),
#              ('X5PL3E', 0.0),
#              ('DOGULNR', 0.0),
#              ('TRE6PP', 0.0),
#              ('EX_fuc__L_e', 0.0),
#              ('EX_met__D_e', 0.0),
#              ('EX_tartr__L_e', 0.0),
#              ('BETALDHx', 0.0),
#              ('BETALDHy', 0.0),
#              ('MLTG3', 0.0),
#              ('EX_taur_e', 0.0),
#              ('EX_maltpt_e', 0.0),
#              ('EX_glyald_e', 0.0),
#              ('EX_glcur_e', 0.0),
#              ('ADPRDP', 0.0),
#              ('DKGLCNR1', 0.0),
#              ('NADTRHD', 0.0),
#              ('AACPS2', 0.0),
#              ('FMNRx2', 0.0),
#              ('ACPS1', 0.0),
#              ('EX_nmn_e', 0.0),
#              ('EX_urea_e', 0.0),
#              ('ARAI', 0.0),
#              ('M1PD', 0.0),
#              ('G3PD2', -0.1219271687273534),
#              ('GALS3', 0.0),
#              ('FCI', 0.0),
#              ('FCLK', 0.0),
#              ('FCLPA', 0.0),
#              ('GMPS2', 0.0),
#              ('AMPN', 0.0),
#              ('GSNK', 0.0),
#              ('ACCOAL', 0.0),
#              ('GALUi', -3.0592259369322904e-32),
#              ('AACPS3', 0.1119294004828859),
#              ('U23GAAT', 0.034125715607782436),
#              ('EX_f6p_e', 0.0),
#              ('UAAGDS', 0.024369998594496768),
#              ('AACPS4', 0.13192493697182092),
#              ('UAMAS', 0.024369998594496768),
#              ('UAMAGS', 0.024369998594496768),
#              ('UGLYCH', 0.0),
#              ('NTPP3', 0.0),
#              ('NTPP6', 0.0),
#              ('NTPP7', 0.0),
#              ('OP4ENH', 0.0),
#              ('EX_rmn_e', 0.0),
#              ('HOPNTAL', 0.0),
#              ('NTPP8', 0.0),
#              ('P5CR', 0.19386461923515486),
#              ('CYANST', 0.0),
#              ('EX_ttdca_e', 0.0),
#              ('DHPPDA2', 0.0003911407576345045),
#              ('3HPPPNH', 0.0),
#              ('G5SADs', 0.19386461923515486),
#              ('GMAND', 0.0),
#              ('PPCSCT', 0.0),
#              ('CYTD', 0.0),
#              ('AKGDH', 5.970062721906824),
#              ('HPYRRx', 0.0),
#              ('GLYCDx', 0.0),
#              ('ASP1DC', 0.0005910961225234471),
#              ('UGMDDS', 0.024369998594496768),
#              ('DCYTD', 0.0),
#              ('DBTS', 1.753994428853949e-06),
#              ('DCTPD', 0.0),
#              ('UHGADA', 0.034125715607782436),
#              ('AMANK', 0.0),
#              ('UAGAAT', 0.034125715607782436),
#              ('ATPPRT', 0.08308496210038271),
#              ('HISTD', 0.08308496210038271),
#              ('DHDPS', 0.32532123969447174),
#              ('G1PACT', 0.08286571279677597),
#              ('GART', 0.0021512741669896533),
#              ('CSND', 0.0),
#              ('GF6PTA', 0.08286571279677597),
#              ('IGPDH', 0.08308496210038271),
#              ('EX_glyclt_e', 0.0),
#              ('PRPPS', 0.8179498689768061),
#              ('H2SO', 0.0),
#              ('GLUCYS', 0.0),
#              ('PRATPP', 0.08308496210038271),
#              ('GLUN', 0.0),
#              ('PRMICI', 0.08308496210038271),
#              ('GLUPRT', 0.3929096610159156),
#              ('EX_g6p_e', 0.0),
#              ('GMPR', 0.0),
#              ('SERAT', 0.21704102462081615),
#              ('CYSS', 0.21704102462081615),
#              ('NADS1', 0.0019977996544642603),
#              ('BPNT', 0.21704102462081615),
#              ('EX_2ddglcn_e', 0.0),
#              ('PAPSR', 0.21704102462081615),
#              ('ASPK', 0.9375766740107322),
#              ('ASAD', -0.9375766740107322),
#              ('DAPDC', 0.300951241099975),
#              ('EX_mmet_e', 0.0),
#              ('NTRIR2x', 0.0),
#              ('OCBT', 0.25940876004978364),
#              ('GARFT', 0.39075838684892217),
#              ('GPDDA1', 0.0),
#              ('GPDDA2', 0.0),
#              ('PHETA1', -0.16247688893081344),
#              ('PPND', 0.12112997825943929),
#              ('METAT', 0.0007875434985554232),
#              ('ASCBPL', 0.0),
#              ('ACBIPGT', 0.0),
#              ('TRPS1', 0.0),
#              ('PRAMPC', 0.08308496210038271),
#              ('ADOCBLS', 0.0),
#              ('EX_galct__D_e', 0.0),
#              ('ADOCBIK', 0.0),
#              ('TMPK', 0.00019557037881721533),
#              ('HPPPNDO', 0.0),
#              ('MCITL2', 0.0),
#              ('DXYLK', 0.0),
#              ('MDH3', 0.0),
#              ('SOTA', 0.0),
#              ('DHCINDO', 0.0),
#              ('SGSAD', 0.0),
#              ('HKNDDH', 0.0),
#              ('EX_idon__L_e', 0.0),
#              ('HKNTDH', 0.0),
#              ('GLYCK2', 0.0),
#              ('PTA2', 0.0),
#              ('MDH2', 0.0),
#              ('EX_indole_e', 0.0),
#              ('ACOTA', -0.25940876004978364),
#              ('GPDDA5', 0.0),
#              ('PDX5PS', 0.00019557037881721533),
#              ('PPBNGS', 0.0015645630305377227),
#              ('ENTCS', 0.0),
#              ('SULR', 0.21704102462081615),
#              ('MANPGH', 0.0),
#              ('URDGLYCD', 0.0),
#              ('CBMKr', 0.5495150535961546),
#              ('PPNCL2', 0.0005910961225234471),
#              ('PRAGSr', 0.3929096610159156),
#              ('PRFGS', 0.39290966101591185),
#              ('AMANAPEr', 0.0),
#              ('EX_3hcinnm_e', 0.0),
#              ('ACM6PH', 0.0),
#              ('NNATr', 0.0019977996544642603),
#              ('CYTDH', 0.0),
#              ('EX_acac_e', 0.0),
#              ('ETHAAL', 0.0),
#              ('MAN1PT2', 0.0),
#              ('PSERT', 1.5065360713465552),
#              ('AP4AH', 0.0),
#              ('EX_acmana_e', 0.0),
#              ('AP5AH', 0.0),
#              ('ADNCYC', 0.0),
#              ('AIRC2', 0.3927140906370946),
#              ('GAPD', 17.10543360355017),
#              ('MI1PP', 0.0),
#              ('EX_galur_e', 0.0),
#              ('MCITS', 0.0),
#              ('PPAKr', 0.0),
#              ('HEX1', 0.0),
#              ('GND', 2.3553662197940564),
#              ('TAUDO', 0.0),
#              ('DM_amob_c', 1.753994428853949e-06),
#              ('NTP3', 0.0),
#              ('PPM2', 0.0),
#              ('MOAT2', 0.017062857803891218),
#              ('EX_adn_e', 0.0),
#              ('EX_ins_e', 0.0),
#              ('G6PDH2r', 2.3553662197940564),
#              ('ME2', 0.0),
#              ('ARGSL', 0.25940876004978364),
#              ('CBPS', 0.0),
#              ('GLU5K', 0.19386461923515486),
#              ('IPPS', 0.3951144320129993),
#              ('EX_mg2_e', -0.007607950835154005),
#              ('ACOATA', 0.0),
#              ('NADH5', 0.0),
#              ('MOHMT', 0.0005910961225234471),
#              ('EX_glyc3p_e', 0.0),
#              ('MLTG2', 0.0),
#              ('EX_but_e', 0.0),
#              ('MLTG1', 0.0),
#              ('AMALT3', 0.0),
#              ('MLTP3', 0.0),
#              ('EX_lcts_e', 0.0),
#              ('EX_ocdca_e', 0.0),
#              ('EX_cbl1_e', 0.0),
#              ('SPODM', 0.0014259974706586484),
#              ('AHCYSNS', 0.0003928947520632846),
#              ('ACNML', 0.0),
#              ('TMK', 0.0),
#              ('NTPP4', 0.0),
#              ('GMPS', 0.21331027847064438),
#              ('CAT', 0.0),
#              ('FTHFLi', 0.0),
#              ('EX_nac_e', 0.0),
#              ('UDPGD', 0.0),
#              ('SERASr', 0.0),
#              ('GLCRD', 0.0),
#              ('PPPNDO', 0.0),
#              ('26DAHtex', 0.0),
#              ('HCINNMtex', 0.0),
#              ('HPPPNtex', 0.0),
#              ('ACtex', 0.0),
#              ('ACALDtex', 0.0),
#              ('CHRPL', 0.00019557037881721533),
#              ('TDPAGTA', 0.0),
#              ('UACMAMO', 0.0),
#              ('FBA3', 0.6119224317254629),
#              ('PMPK', 0.00019557037881721533),
#              ('LCADi', 0.0),
#              ('ACMANAtex', 0.0),
#              ('ACMUMtex', 0.0),
#              ('ACACT7r', 0.2438543374547068),
#              ('PSP_L', 1.5065360713465552),
#              ('ADK3', 0.0),
#              ('GLUDC', 0.0),
#              ('ACACT2r', 0.3121057686702717),
#              ('BSORy', 0.0),
#              ('DMSOR2', 0.0),
#              ('ADSK', 0.21704102462081615),
#              ('ACACT3r', 0.3121057686702717),
#              ('ACACT4r', 0.3121057686702717),
#              ('SUCCt2_2pp', 0.0),
#              ('SUCFUMtpp', 0.0),
#              ('HSDy', -0.6122554343162605),
#              ('CYSTL', 0.13497951826967008),
#              ('ACMAMUT', 0.0),
#              ('SHSL1', 0.13497951826967008),
#              ('SSALy', 0.0),
#              ('SUCptspp', 0.0),
#              ('SULabcpp', 0.0),
#              ('TSULabcpp', 0.0),
#              ('TARTRt7pp', 0.0),
#              ('EX_dad_2_e', 0.0),
#              ('EX_ser__D_e', 0.0),
#              ('DDGALK', 0.0),
#              ('EX_gam6p_e', 0.0),
#              ('EX_15dap_e', 0.0),
#              ('AB6PGH', 0.0),
#              ('EX_ocdcea_e', 0.0),
#              ('EX_cynt_e', 0.0),
#              ('EX_galctn__D_e', 0.0),
#              ('AMALT1', 0.0),
#              ('EX_glyb_e', 0.0),
#              ('AHGDx', 0.0),
#              ('MLTP2', 0.0),
#              ('TAURabcpp', 0.0),
#              ('THMDt2pp_copy1', 0.0),
#              ('3HCINNMH', 0.0),
#              ('BSORx', 0.0),
#              ('PACCOAL', 0.0),
#              ('NMNt7pp', 0.0),
#              ('EX_ca2_e', -0.004564770501092403),
#              ('EX_so3_e', 0.0),
#              ('GLUtex', 0.0),
#              ('Kt2pp', 0.17118371727564444),
#              ('GLYtex', 0.0),
#              ('GP4GH', 0.0),
#              ('GLYALDtex', 0.0),
#              ('AKGt2rpp', 0.0),
#              ('ACGAMT', 0.0),
#              ('XYLt2pp', 0.0),
#              ('EX_ascb__L_e', 0.0),
#              ('GLYBtex', 0.0),
#              ('GLYCtex', 0.0),
#              ('GLYC3Ptex', 0.0),
#              ('GLYCLTtex', 0.0),
#              ('GTPtex', 0.0),
#              ('GUAtex', 0.0),
#              ('Htex', -8.058200328043558),
#              ('EX_ala_B_e', 0.0),
#              ('EX_agm_e', 0.0),
#              ('EX_minohp_e', 0.0),
#              ('EX_ppt_e', 0.0),
#              ('EX_hxa_e', 0.0),
#              ('H2tex', 0.0),
#              ('H2Otex', -47.16236480869429),
#              ('AADDGT', 0.0),
#              ('FACOAL160t2pp', 0.0),
#              ('FACOAL180t2pp', 0.0),
#              ('SPODMpp', 0.0),
#              ('EX_lyx__L_e', 0.0),
#              ('EX_acmum_e', 0.0),
#              ('EX_dca_e', 0.0),
#              ('EX_all__D_e', 0.0),
#              ('NO3R1bpp', 0.0),
#              ('O2tpp', 22.13176323894588),
#              ('EX_octa_e', 0.0),
#              ('PHYTSpp', 0.0),
#              ('EX_gbbtn_e', 0.0),
#              ('PPTHpp', 0.0),
#              ('PYRt2rpp', 0.0),
#              ('NO3R2pp', 0.0),
#              ('EX_xylu__L_e', 0.0),
#              ('EX_gdp_e', 0.0),
#              ('EX_gtp_e', 0.0),
#              ('NTP3pp', 0.0),
#              ('NO3R2bpp', 0.0),
#              ('THMabcpp', 0.0),
#              ('THMDt2pp_copy2', 0.0),
#              ('THRabcpp', 0.0),
#              ('TREptspp', 0.0),
#              ('THD2pp', 0.0),
#              ('TMAOR1pp', 0.0),
#              ('TMAOR2pp', 0.0),
#              ('XANtpp', 0.0),
#              ('DAPtex', 0.0),
#              ('TRPt2rpp', 0.0),
#              ('TYRt2rpp', 0.0),
#              ('EX_tma_e', 0.0),
#              ('URIt2pp_copy1', 0.0),
#              ('URIt2pp_copy2', 0.0),
#              ('VALabcpp', 0.0),
#              ('12PPDStex', 0.0),
#              ('DDGLCNtex', 0.0),
#              ('XTSNt2rpp', 0.0),
#              ('XYLabcpp', 0.0),
#              ('GMHEPK', -3.0592259369322904e-32),
#              ('XYLUt2pp', 0.0),
#              ('THRt4pp', 0.0),
#              ('GALURtex', 0.0),
#              ('GTPCI', 0.0005867111364517094),
#              ('FDMO', 0.0),
#              ('FEOXAMabcpp', 0.0),
#              ('EX_fruur_e', 0.0),
#              ('GALtex', 0.0),
#              ('CBL1abcpp', 0.0),
#              ('EX_malttr_e', 0.0),
#              ('ACACt2pp', 0.0),
#              ('ACGAptspp', 0.0),
#              ('ACMANAptspp', 0.0),
#              ('ACNAMt2pp', 0.0),
#              ('GALCTtex', 0.0),
#              ('GALCTNtex', 0.0),
#              ('GALTtex', 0.0),
#              ('EX_cbi_e', 0.0),
#              ('CHOLD', 0.0),
#              ('TRE6PS', 0.0),
#              ('DRPA', 0.0),
#              ('TKT2', 0.2780732711179619),
#              ('EX_arbtn_fe3_e', 0.0),
#              ('UDCPDP', 0.024369998594496768),
#              ('EX_cpgn_e', 0.0),
#              ('EX_ch4_e', 0.0),
#              ('FEENTERabcpp', 0.0),
#              ('EX_adocbl_e', 0.0),
#              ('FECRMabcpp', 0.0),
#              ('TREH', 0.0),
#              ('GAMtex', 0.0),
#              ('GBBTNtex', 0.0),
#              ('ATPS4rpp', 70.43249366231511),
#              ('INDOLEtex', 0.0),
#              ('ARBt2rpp', 0.0),
#              ('CYTK1', 0.15873912680292532),
#              ('DAPabcpp', 0.0),
#              ('L_LACtex', 0.0),
#              ('ACt4pp', 0.0),
#              ('ADEt2rpp', 0.0),
#              ('CO2tpp', -24.003293272975984),
#              ('DHAtpp', 0.0),
#              ('DMSOR1pp', 0.0),
#              ('ARGabcpp', 0.0),
#              ('ADNt2pp_copy1', 0.0),
#              ('ADNt2pp_copy2', 0.0),
#              ('ALAabcpp', 0.0),
#              ('ALLabcpp', 0.0),
#              ('ALLTNt2rpp', 0.0),
#              ('ARBabcpp', 0.0),
#              ('ARGAGMt7pp', 0.0),
#              ('ASCBptspp', 0.0),
#              ('CYTK2', 0.0),
#              ('ASNt2rpp', 0.0),
#              ('ASPabcpp', 0.0),
#              ('ASPt2pp', 0.0),
#              ('ECOAH8', 0.0),
#              ('GLCDpp', 0.0),
#              ('GUAtpp', 0.0),
#              ('ASPt2_2pp', 0.0),
#              ('HYD2pp', 0.0),
#              ('GK1', 0.21331027847064438),
#              ('HYXNtpp', 0.0),
#              ('NACtpp', 0.0),
#              ('ASPt2_3pp', 0.0),
#              ('HIStex', 0.0),
#              ('FE3DCITabcpp', 0.0),
#              ('HXAtex', 0.0),
#              ('HACD1', 0.3121057686702717),
#              ('HYXNtex', 0.0),
#              ('IDONtex', 0.0),
#              ('ILEtex', 0.0),
#              ('INSTtex', 0.0),
#              ('INStex', 0.0),
#              ('Ktex', 0.17118371727564444),
#              ('CPGNtonex', 0.0),
#              ('GLCRtex', 0.0),
#              ('GLCNtex', 0.0),
#              ('GLCURtex', 0.0),
#              ('GLNtex', 0.0),
#              ('O2tex', 22.13176323894588),
#              ('EX_ppa_e', 0.0),
#              ('HACD2', 0.3121057686702717),
#              ('OCTAtex', 0.0),
#              ('D_LACtex', 0.0),
#              ('NTD8pp', 0.0),
#              ('ORNtex', 0.0),
#              ('FRULYStex', 0.0),
#              ('MALTtexi', 0.0),
#              ('ECOAH5', 0.3121057686702717),
#              ('DHFS', 0.0005867111364517094),
#              ('CITt7pp', 0.0),
#              ('CRNt7pp', 0.0),
#              ('EX_ni2_e', -0.00028327010025991275),
#              ('GLCtex_copy1', 10.0),
#              ('EX_no_e', 0.0),
#              ('CHLabcpp', 0.0),
#              ('DGSNt2pp', 0.0),
#              ('FE3DCITtonex', 0.0),
#              ('DINSt2pp', 0.0),
#              ('DURIt2pp', 0.0),
#              ('FE2abcpp', 0.0),
#              ('FRUptspp', 0.0),
#              ('FUCtpp', 0.0),
#              ('EX_fad_e', 0.0),
#              ('GALCTt2rpp', 0.0),
#              ('GALt2pp', 0.0),
#              ('ASPtex', 0.0),
#              ('ABUTt2pp', 0.0),
#              ('FUMt2_2pp', 0.0),
#              ('FUMt2_3pp', 0.0),
#              ('PHEtex', 0.0),
#              ('FEENTERtonex', 0.0),
#              ('CSNt2pp', 0.0),
#              ('CYNTt2pp', 0.0),
#              ('CYSabcpp', 0.0),
#              ('SBTptspp', 0.0),
#              ('PItex', 0.845956775019459),
#              ('TREHpp', 0.0),
#              ('CYTBDpp', 0.0),
#              ('CYTDt2pp_copy1', 0.0),
#              ('CYTDt2pp_copy2', 0.0),
#              ('DADNt2pp', 0.0),
#              ('DCYTt2pp', 0.0),
#              ('CYTBD2pp', 0.0),
#              ('ACGAMK', 0.0),
#              ('ACALDtpp', 0.0),
#              ('ACt2rpp', 0.0),
#              ('DDGLCNt2rpp', 0.0),
#              ('RMNtex', 0.0),
#              ('EX_meoh_e', 1.753994428853949e-06),
#              ('EX_fe3dcit_e', 0.0),
#              ('EX_fe3hox_e', 0.0),
#              ('EX_fecrm_e', 0.0),
#              ('EX_feenter_e', 0.0),
#              ('EX_feoxam_e', 0.0),
#              ('MALTTRtexi', 0.0),
#              ('MALTTTRtexi', 0.0),
#              ('MALTPTtexi', 0.0),
#              ('METS', 0.13537241302173336),
#              ('ASPO3', 0.0),
#              ('ASPO5', 0.0),
#              ('ASPO4', 0.0),
#              ('EX_3amp_e', 0.0),
#              ('EX_3gmp_e', 0.0),
#              ('EX_3ump_e', 0.0),
#              ('ASPO6', 0.0019977996544642603),
#              ('EX_cu2_e', -0.000621791025028725),
#              ('LCTStex', 0.0),
#              ('LEUtex', 0.0),
#              ('LYStex', 0.0),
#              ('EX_glyc__R_e', 0.0),
#              ('EX_eca4colipa_e', 0.0),
#              ('GLYOX3', 0.0),
#              ('FDMO3', 0.0),
#              ('LYXtex', 0.0),
#              ('MANtex', 0.0),
#              ('MAN6Ptex', 0.0),
#              ('FDMO4', 0.0),
#              ('CYSabc2pp', 0.0),
#              ('BUTSO3abcpp', 0.0),
#              ('ETHSO3abcpp', 0.0),
#              ('MELIBtex', 0.0),
#              ('DMSOtex', 0.0),
#              ('DURItex', 0.0),
#              ('EX_mal__D_e', 0.0),
#              ('FRUtex', 0.0),
#              ('FUCtex', 0.0),
#              ('EX_sel_e', 0.0),
#              ('EX_hg2_e', 0.0),
#              ('O16GLCT1', 0.0),
#              ('O16AP2pp', 0.0),
#              ('O16AP3pp', 0.0),
#              ('FUMtex', 0.0),
#              ('ACACT5r', 0.3121057686702717),
#              ('O16A4Lpp', 0.0),
#              ('PRASCSi', 0.3927140906370946),
#              ('MALTATr', 0.0),
#              ('DHBSH', 0.0),
#              ('MALDDH', 0.0),
#              ('FE2tex', 0.014085452260911638),
#              ('NMNtex', 0.0),
#              ('ENTERES', 0.0),
#              ('NO2tex', 0.0),
#              ('TRSARr', 0.0),
#              ('DHPS2', 0.0005867111364517094),
#              ('FEOXAMUtex', 0.0),
#              ('ARBTNtpp', 0.0),
#              ('MTHFC', 0.8667530099652168),
#              ('ARBTNtex', 0.0),
#              ('MTHFD', 0.8667530099652168),
#              ('LYXI', 0.0),
#              ('BUTt2rpp', 0.0),
#              ('CADVtpp', 0.0),
#              ('QULNS', 0.0019977996544642603),
#              ('23CAMPtex', 0.0),
#              ('23CCMPtex', 0.0),
#              ('23CUMPtex', 0.0),
#              ('23CGMPtex', 0.0),
#              ('3AMPtex', 0.0),
#              ('3CMPtex', 0.0),
#              ('LADGMDH', 0.0),
#              ('ALKP', 0.0),
#              ('GDPtex', 0.0),
#              ('EX_cobalt2_e', -2.1924930360674364e-05),
#              ('ALAGLUE', 0.0),
#              ('FEENTERtpp', 0.0),
#              ('TMAtex', 0.0),
#              ('EX_pheme_e', 0.0),
#              ('TMAOtex', 0.0),
#              ('TREtex', 0.0),
#              ('L_LACD3', 0.0),
#              ('FEENTERtex', 0.0),
#              ('FE3HOXUtpp', 0.0),
#              ('FEOXAMUtpp', 0.0),
#              ('FECRMUtpp', 0.0),
#              ('FE3HOXR2', 0.0),
#              ('L_LACD2', 0.0),
#              ('ACACT6r', 0.2438543374547068),
#              ('TRPtex', 0.0),
#              ('PTRCt2pp', 0.0),
#              ('GGGABAH', 0.0),
#              ('PNTOtex', 0.0),
#              ('FRULYSK', 0.0),
#              ('FDMO6', 0.0),
#              ('TSULtex', 0.0),
#              ('TYRtex', 0.0),
#              ('URAtex', 0.0),
#              ('UREAtex', 0.0),
#              ('URItex', 0.0),
#              ('SULFACabcpp', 0.0),
#              ('ETHSO3tex', 0.0),
#              ('BUTSO3tex', 0.0),
#              ('LIPOtex', 0.0),
#              ...])

# %%
result.data_frame
# Out:
#      Reaction ID     Flux
# 0         CYTDK2  0.00000
# 1           XPPT  0.00000
# 2          HXPRT  0.00000
# 3          NDPK5  0.00000
# 4         SHK3Dr  0.33424
# ...          ...      ...
# 2707        MPTS  0.00000
# 2708       MOCOS  0.00000
# 2709     BMOGDS2  0.00000
# 2710      FESD2s  0.00000
# 2711      OCTNLL  0.00000
#
# [2712 rows x 2 columns]

# %% [markdown]
# Individual reaction flux values can be obtained from the dictionary representation. For example, the *Prephenate dehydratase* reaction flux can be obtained from the previous pFBA simulation using the reaction identifier:

# %%
result.fluxes['PPNDH']
# Out:
# 0.16247688893081344

# %% [markdown]
# ## Retrieving and setting the model objective
#
# The simulation objective, when running FBA or pFBA phenotype simulations, is, by default, the model objective which can be seen using the simulator.

# %%
simul.objective
# Out:
# {'BIOMASS_Ec_iML1515_core_75p37M': 1.0}

# %% [markdown]
# The simulator may also be used to change the model objective, for example, to optimize the ATP maintenance requirement (ATPM):

# %%
simul.objective = 'ATPM'

# %%
simul.objective
# Out:
# {'ATPM': 1.0}

# %%
simul.objective='BIOMASS_Ec_iML1515_core_75p37M'

# %% [markdown]
# ## Adding additional constraints to phenotype simulations
#
# Simulations may include additional metabolic constraints on reaction fluxes. From the previous pFBA simulation one can observe that the organism does not produce L-tyrosine:

# %%
result.fluxes['EX_tyr__L_e']
# Out:
# 0.0

# %% [markdown]
# Additional constraints may be added to the model so that the organism start to produce this aromatic amino acid. We may alter, for example, the *3-dehydroquinate dehydratase* reaction bounds, among others, starting by verifying its initial bounds:

# %%
simul.get_reaction_bounds('DHQTi')
# Out:
# (0.0, 1000.0)

# %%
constraints = {'DHQTi': (1, 10000),
               'PPC': (16.791619483918264, 10000),
               'FADRx2': (0, 0.0),
               'PDH': (0, 0)}

# run a pFBA simulation accounting with the new constraint
result = simul.simulate(method='pFBA',constraints=constraints)

result.fluxes['EX_tyr__L_e']
# Out:
# 0.7362937237983241

# %% [markdown]
# Note that the modifications are not persistently applied to the model, they only exist during the simulation.
#
# We also need to verify that the organism continues to grow:

# %%
result.fluxes['BIOMASS_Ec_iML1515_core_75p37M']
# Out:
# 0.691926343744802

# %% [markdown]
# We can also plot the production envelope:

# %%
# %matplotlib inline
from mewpy.visualization.envelope import plot_flux_envelope

plot_flux_envelope(simul,'BIOMASS_Ec_iML1515_core_75p37M','EX_tyr__L_e',constraints = constraints)
# Out:
# <AxesSubplot:xlabel='BIOMASS_Ec_iML1515_core_75p37M', ylabel='EX_tyr__L_e'>

# %% [markdown]
# The `simulate` method includes additional parameters, such as the optimization direction. For a full description please refer to the module documentation.

# %% [markdown]
# ## Flux Variability Analysis
#
# The simulator interface also allows to perform Flux Variability Analysis (FVA) for L-tyrosine:

# %%
# returns a dictionar
simul.FVA(reactions=['EX_tyr__L_e'])
# Out:
# {'EX_tyr__L_e': [0.0, 0.5721226993865252]}

# %%
# or a data frame
simul.FVA(reactions=['EX_tyr__L_e'],format='df')
# Out:
#    Reaction ID  Minimum   Maximum
# 0  EX_tyr__L_e      0.0  0.572123

# %% [markdown]
# By default, MEWpy sets the model objective fraction to 90%, however this fraction may be altered. For example, one might want to consider a fraction of 10% from optimal growth:

# %%
simul.FVA(reactions=['EX_tyr__L_e'],obj_frac=0.1)
# Out:
# {'EX_tyr__L_e': [0.0, 5.086103322262054]}

# %% [markdown]
# The FVA simulations are run considering the defined environmental conditions. Additional constraints may be added, or changed, such as the previouly used to increase L-tyrosine production.

# %%
simul.FVA(reactions=['EX_tyr__L_e'], constraints=constraints)
# Out:
# {'EX_tyr__L_e': [0.0, 1.1883110320942545]}

# %% [markdown]
# COBRApy users may have noticed that this same task would have required many additional coding lines if using the COBRApy API directly.

# %% [markdown]
# ## Genes and reactions essentiality
#
# Gene and reaction essentiality tests identify, respectively, the list of genes and reactions whose deletion would prevent the organism to grow.

# %%
simul.essential_reactions
# Out:
# ['SHK3Dr',
#  'DHORTS',
#  'OMPDC',
#  'G5SD',
#  'CS',
#  'ICDHyr',
#  'PPA',
#  'APRAUR',
#  'DB4PS',
#  'ALAR',
#  'RBFK',
#  'ASPTA',
#  'RBFSb',
#  'EX_pi_e',
#  'SHCHD2',
#  'A5PISO',
#  'PMDPHT',
#  'ILETA',
#  'IPPMIb',
#  'ORPT',
#  'RBFSa',
#  'ACHBS',
#  'DHAD2',
#  'ACLS',
#  'PSCVT',
#  'ANS',
#  'ANPRT',
#  'CHORM',
#  'CHORS',
#  'IGPS',
#  'LEUTAi',
#  'DMATT',
#  'GRTT',
#  'UPP3S',
#  'UPPDC1',
#  'EX_mn2_e',
#  'MOAT',
#  'UDCPDPS',
#  'USHD',
#  'HCO3E',
#  'IMPC',
#  'LPADSS',
#  'GLUTRS',
#  'TDSK',
#  'TMPPP',
#  'DHQTi',
#  'IPMD',
#  'AIRC3',
#  'ADSL2r',
#  'TMDS',
#  'PPCDC',
#  'DHAD1',
#  'IPPMIa',
#  'FMNAT',
#  'KARA1',
#  'KARA2',
#  'ACCOAC',
#  'NADK',
#  'GLUTRR',
#  'ARGSS',
#  'AGPR',
#  'G1SAT',
#  'KDOCT2',
#  'DXPS',
#  'CDPMEK',
#  'MECDPS',
#  'PGAMT',
#  'UAGDP',
#  'UAGCVT',
#  'GLUR',
#  'NNDPR',
#  'EX_zn2_e',
#  'DNMPPA',
#  'HPPK2',
#  'PTPATi',
#  'DXPRIi',
#  'GTPCII2',
#  'SADT2',
#  'OPHBDC',
#  'SDPDS',
#  'ADCS',
#  'ADCL',
#  'UMPK',
#  'UAPGR',
#  'CTPS2',
#  'PAPPT3',
#  'UAGPT3',
#  'ACODA',
#  'FCLT',
#  'HBZOPT',
#  'PNTK',
#  'ADSS',
#  'OCTDPS',
#  'DPCOAK',
#  'ASPCT',
#  'KDOPS',
#  'KDOPP',
#  'MCOATA',
#  'DAPE',
#  'DHDPRy',
#  'HSK',
#  'SDPTA',
#  'THRS',
#  'HSST',
#  'PPNDH',
#  'DTMPK',
#  'DDPA',
#  'RHCCE',
#  'U23GAAT',
#  'UAAGDS',
#  'UAMAS',
#  'UAMAGS',
#  'P5CR',
#  'DHPPDA2',
#  'G5SADs',
#  'ASP1DC',
#  'UGMDDS',
#  'DBTS',
#  'UHGADA',
#  'UAGAAT',
#  'ATPPRT',
#  'HISTD',
#  'DHDPS',
#  'G1PACT',
#  'GF6PTA',
#  'IGPDH',
#  'PRATPP',
#  'PRMICI',
#  'GLUPRT',
#  'SERAT',
#  'CYSS',
#  'NADS1',
#  'BPNT',
#  'ASPK',
#  'ASAD',
#  'DAPDC',
#  'OCBT',
#  'PHETA1',
#  'PPND',
#  'METAT',
#  'PRAMPC',
#  'TMPK',
#  'ACOTA',
#  'PDX5PS',
#  'PPBNGS',
#  'SULR',
#  'PPNCL2',
#  'PRAGSr',
#  'PRFGS',
#  'NNATr',
#  'AIRC2',
#  'DM_amob_c',
#  'MOAT2',
#  'ARGSL',
#  'GLU5K',
#  'IPPS',
#  'EX_mg2_e',
#  'MOHMT',
#  'AHCYSNS',
#  'CHRPL',
#  'PMPK',
#  'ADSK',
#  'HSDy',
#  'CYSTL',
#  'SHSL1',
#  'EX_ca2_e',
#  'GTPCI',
#  'UDCPDP',
#  'GK1',
#  'Ktex',
#  'DHFS',
#  'EX_ni2_e',
#  'PItex',
#  'EX_meoh_e',
#  'METS',
#  'EX_cu2_e',
#  'PRASCSi',
#  'DHPS2',
#  'QULNS',
#  'EX_cobalt2_e',
#  'SO4tex',
#  'NH4tpp',
#  'MOBDabcpp',
#  'MOBDtex',
#  'NI2tex',
#  'DNTPPA',
#  'NH4tex',
#  'MG2tex',
#  'Zn2tex',
#  'ACGK',
#  'COBALT2tex',
#  'HMBS',
#  'MEPCT',
#  'HSTPT',
#  'THDPS',
#  'THRD_L',
#  'DHFR',
#  'PRAIi',
#  'TYRTA',
#  'SHKK',
#  'EX_mobd_e',
#  'EX_so4_e',
#  'OMCDC',
#  'IG3PS',
#  'MTHFR2',
#  'EX_nh4_e',
#  'DPR',
#  'AMAOTr',
#  'GLNS',
#  'EX_k_e',
#  'ACGS',
#  'CU2tex',
#  'ALAALAr',
#  'CLtex',
#  'MNtex',
#  'SHCHF',
#  'PRAIS',
#  'PANTS',
#  'HISTP',
#  'UPP3MT',
#  'DHQS',
#  'DASYN160',
#  'DASYN161',
#  'ADSL1r',
#  'AICART',
#  'EX_cl_e',
#  'MPTG',
#  'MCTP1App',
#  '5DOAN',
#  'DM_5drib_c',
#  'K2L4Aabcpp',
#  'AMPMS2',
#  'PSSA161',
#  'PSD160',
#  'PSD161',
#  'ACONTb',
#  'CA2tex',
#  'AGPAT160',
#  '3OAS140',
#  '3OAR140',
#  'PE160abcpp',
#  'PE161abcpp',
#  'ACONTa',
#  'PSSA160',
#  'AGPAT161',
#  'CAt6pp',
#  'COBALT2tpp',
#  'MALCOAMT',
#  'CU2tpp',
#  'OGMEACPS',
#  'OGMEACPR',
#  'OPMEACPS',
#  'K2L4Aabctex',
#  'OPMEACPD',
#  'EPMEACPR',
#  'AOXSr2',
#  'MEOHtrpp',
#  'OGMEACPD',
#  'EGMEACPR',
#  'OPMEACPR',
#  'PMEACPE',
#  'MEOHtex',
#  'ICYSDS',
#  'MECDPDH5',
#  'BTS5',
#  'DM_4crsol_c',
#  'DHNPA2r',
#  'TYRL',
#  'THZPSN3',
#  'BIOMASS_Ec_iML1515_core_75p37M']

# %%
simul.essential_genes
# Out:
# ['b3368',
#  'b1260',
#  'b0109',
#  'b1094',
#  'b2472',
#  'b1261',
#  'b3770',
#  'b0243',
#  'b0414',
#  'b3041',
#  'b0025',
#  'b1662',
#  'b0421',
#  'b3804',
#  'b3997',
#  'b3187',
#  'b4006',
#  'b2400',
#  'b3993',
#  'b1062',
#  'b1281',
#  'b0639',
#  'b0720',
#  'b1136',
#  'b2103',
#  'b3642',
#  'b0415',
#  'b3648',
#  'b3771',
#  'b3972',
#  'b0071',
#  'b0072',
#  'b0908',
#  'b1263',
#  'b1264',
#  'b2599',
#  'b2600',
#  'b2329',
#  'b3633',
#  'b1262',
#  'b0174',
#  'b0524',
#  'b0182',
#  'b0915',
#  's0001',
#  'b2026',
#  'b0523',
#  'b1131',
#  'b2024',
#  'b3607',
#  'b4214',
#  'b2762',
#  'b2827',
#  'b3433',
#  'b3639',
#  'b2838',
#  'b4040',
#  'b3974',
#  'b0103',
#  'b1693',
#  'b2942',
#  'b1215',
#  'b3198',
#  'b0417',
#  'b1098',
#  'b1210',
#  'b0522',
#  'b2687',
#  'b3960',
#  'b3172',
#  'b0242',
#  'b0074',
#  'b3958',
#  'b1091',
#  'b0154',
#  'b0918',
#  'b0159',
#  'b3176',
#  'b3730',
#  'b3189',
#  'b3967',
#  'b2763',
#  'b0386',
#  'b2764',
#  'b2323',
#  'b2507',
#  'b0142',
#  'b3634',
#  'b0778',
#  'b0173',
#  'b1812',
#  'b3360',
#  'b3843',
#  'b2478',
#  'b3729',
#  'b2312',
#  'b1740',
#  'b2780',
#  'b0087',
#  'b0090',
#  'b3774',
#  'b2316',
#  'b3255',
#  'b0185',
#  'b3256',
#  'b0052',
#  'b2564',
#  'b2615',
#  'b0369',
#  'b4005',
#  'b2557',
#  'b3957',
#  'b4177',
#  'b4245',
#  'b0029',
#  'b0134',
#  'b0420',
#  'b1092',
#  'b3809',
#  'b0031',
#  'b0003',
#  'b1208',
#  'b2746',
#  'b0004',
#  'b4013',
#  'b2750',
#  'b3939',
#  'b0179',
#  'b0085',
#  'b0091',
#  'b1277',
#  'b0088',
#  'b2752',
#  'b2751',
#  'b0131',
#  'b0086',
#  'b0096',
#  'b0181',
#  'b2019',
#  'b2020',
#  'b2022',
#  'b2153',
#  'b3805',
#  'b2747',
#  'b2023',
#  'b2025',
#  'b0774',
#  'b2315',
#  'b2818',
#  'b0133',
#  'b2476',
#  'b3389',
#  'b3941',
#  'b2574',
#  'b3177',
#  'b0750',
#  'b3870',
#  'b0914',
#  'b3850',
#  'b3959',
#  'b2499',
#  'b1288',
#  'b0175',
#  'b0089',
#  'b1069',
#  'b2585',
#  'b1093',
#  'b0635',
#  'b0084',
#  'b2021',
#  'b0166',
#  'b3994',
#  'b0180',
#  'b3018',
#  'b4160',
#  'b3040',
#  'b3196',
#  'b0777',
#  'b0641',
#  'b3201',
#  'b3200',
#  'b4261',
#  'b4262',
#  'b3199',
#  'b0054',
#  'b2530',
#  'b3058',
#  'b0775',
#  'b3991',
#  'b3992',
#  'b0423',
#  'b3990',
#  'b4407',
#  'b0776',
#  'b3412',
#  'b2515']

# %% [markdown]
# For more options and methods please refer to the MEWpy documentation
