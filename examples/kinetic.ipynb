# %% [markdown]
# # Kinetic Models in MEWpy

# %%
# check for ODE solvers:
import mewpy
mewpy.info()
# Out:
# MEWpy version: 0.1.20
# Author: BiSBII CEB University of Minho
# Contact: vpereira@ceb.uminho.pt
#
# Available LP solvers: gurobi cplex glpk
# Default LP solver: cplex
#
# Available ODE solvers: scipy
# Default ODE solver: scipy
#
# Optimization Problems: AbstractKOProblem AbstractOUProblem CommunityKOProblem ETFLGKOProblem ETFLGOUProblem GKOProblem GOUProblem GeckoKOProblem GeckoOUProblem KineticKOProblem KineticOUProblem MediumProblem OptORFProblem OptRamProblem RKOProblem ROUProblem
#
# Available EA engines: inspyred jmetal
# Default EA engine: jmetal
# Available EAs: GA NSGAII NSGAIII SA SPEA2

# %% [markdown]
# Load the model

# %%
from mewpy.io.sbml import load_ODEModel
model = load_ODEModel('models/kinetic/chassagnole2002.xml')

# %% [markdown]
# List/find metabolites

# %%
model.find_metabolites()
# Out:
#                                name    compartment formula charge     y0
# id
# cpep           Phosphoenol pyruvate        cytosol                 2.670
# cglcex        Extracellular Glucose  extracellular                 2.000
# cg6p            Glucose-6-Phosphate        cytosol                 3.480
# cpyr                       Pyruvate        cytosol                 2.670
# cf6p           Fructose-6-Phosphate        cytosol                 0.600
# cg1p            Glucose-1-Phosphate        cytosol                 0.653
# cpg              6-Phosphogluconate        cytosol                 0.808
# cfdp      Fructose-1,6-bisphosphate        cytosol                 0.272
# csed7p    sedoheptulose-7-phosphate        cytosol                 0.276
# cgap     Glyceraldehyde-3-Phosphate        cytosol                 0.218
# ce4p          Erythrose-4-phosphate        cytosol                 0.098
# cxyl5p         Xylulose-5-phosphate        cytosol                 0.138
# crib5p           Ribose-5-phosphate        cytosol                 0.398
# cdhap     Dihydroxyacetonephosphate        cytosol                 0.167
# cpgp     1,3-diphosphosphoglycerate        cytosol                 0.008
# cpg3             3-Phosphoglycerate        cytosol                 2.130
# cpg2             2-Phosphoglycerate        cytosol                 0.399
# cribu5p        Ribulose-5-phosphate        cytosol                 0.111

# %% [markdown]
# List/find all or a set of reactions by pattern

# %%
model.find()
# Out:
#                                                  name  \
# id
# vPTS                        Phosphotransferase system
# vPGI                    Glucose-6-phosphate isomerase
# vPGM                               Phosphoglucomutase
# vG6PDH              Glucose-6-phosphate dehydrogenase
# vPFK                              Phosphofructokinase
# vTA                                     Transaldolase
# vTKA                                  Transketolase a
# vTKB                                  Transketolase b
# vMURSyNTH                           Mureine synthesis
# vALDO                                        Aldolase
# vGAPDH       Glyceraldehyde-3-phosphate dehydrogenase
# vTIS                        Triosephosphate isomerase
# vTRPSYNTH                        Tryptophan synthesis
# vG3PDH             Glycerol-3-phosphate dehydrogenase
# vPGK                          Phosphoglycerate kinase
# vsersynth                            Serine synthesis
# vrpGluMu                      Phosphoglycerate mutase
# vENO                                          Enolase
# vPK                                   Pyruvate kinase
# vpepCxylase                           PEP carboxylase
# vSynth1                                   Synthesis 1
# vSynth2                                   Synthesis 2
# vDAHPS                                 DAHP synthesis
# vPDH                           Pyruvate dehydrogenase
# vMethSynth                       Methionine synthesis
# vPGDH                6-Phosphogluconate dehydrogenase
# vR5PI                      Ribose-phosphate isomerase
# vRu5P                    Ribulose-phosphate epimerase
# vPPK               Ribose phosphate pyrophosphokinase
# vG1PAT          Glucose-1-phosphate adenyltransferase
# vG6P                                  G6P degradation
# vf6P                                  F6P degradation
# vfdP                                  FDP degradation
# vGAP                                  GAP degradation
# vDHAP                                DHAP degradation
# vPGP                                  PGP degradation
# vPG3                                  PG3 degradation
# vpg2                                  PG2 degradation
# vPEP                                  PEP degradation
# vRibu5p                               Ribu5P dilution
# vRIB5P                                 Rib5P dilution
# vXYL5P                                 XYL5P dilution
# vSED7P                                 SED7P dilution
# vpyr                                Pyruvate dilution
# vPG                                       PG dilution
# vE4P                                     E4P dilution
# vGLP                                     GLP dilution
# vEXTER                 Extracellular glucose kinetics
#
#                                                  stoichiometry  \
# id
# vPTS         {'cglcex': -1.0, 'cpep': -1.0, 'cg6p': 1.0, 'c...
# vPGI                               {'cg6p': -1.0, 'cf6p': 1.0}
# vPGM                               {'cg6p': -1.0, 'cg1p': 1.0}
# vG6PDH                              {'cg6p': -1.0, 'cpg': 1.0}
# vPFK                               {'cf6p': -1.0, 'cfdp': 1.0}
# vTA          {'cgap': -1.0, 'csed7p': -1.0, 'cf6p': 1.0, 'c...
# vTKA         {'crib5p': -1.0, 'cxyl5p': -1.0, 'cgap': 1.0, ...
# vTKB         {'ce4p': -1.0, 'cxyl5p': -1.0, 'cgap': 1.0, 'c...
# vMURSyNTH                                       {'cf6p': -2.0}
# vALDO                {'cfdp': -1.0, 'cdhap': 1.0, 'cgap': 1.0}
# vGAPDH                             {'cgap': -1.0, 'cpgp': 1.0}
# vTIS                              {'cdhap': -1.0, 'cgap': 1.0}
# vTRPSYNTH                           {'cpyr': 1.0, 'cgap': 1.0}
# vG3PDH                                         {'cdhap': -1.0}
# vPGK                               {'cpgp': -1.0, 'cpg3': 1.0}
# vsersynth                                       {'cpg3': -1.0}
# vrpGluMu                           {'cpg3': -1.0, 'cpg2': 1.0}
# vENO                               {'cpg2': -1.0, 'cpep': 1.0}
# vPK                                {'cpep': -1.0, 'cpyr': 1.0}
# vpepCxylase                                     {'cpep': -1.0}
# vSynth1                                         {'cpep': -1.0}
# vSynth2                                         {'cpyr': -1.0}
# vDAHPS                            {'ce4p': -1.0, 'cpep': -1.0}
# vPDH                                            {'cpyr': -1.0}
# vMethSynth                                       {'cpyr': 1.0}
# vPGDH                            {'cpg': -1.0, 'cribu5p': 1.0}
# vR5PI                         {'cribu5p': -1.0, 'crib5p': 1.0}
# vRu5P                         {'cribu5p': -1.0, 'cxyl5p': 1.0}
# vPPK                                          {'crib5p': -1.0}
# vG1PAT                                          {'cg1p': -1.0}
# vG6P                                            {'cg6p': -1.0}
# vf6P                                            {'cf6p': -1.0}
# vfdP                                            {'cfdp': -1.0}
# vGAP                                            {'cgap': -1.0}
# vDHAP                                          {'cdhap': -1.0}
# vPGP                                            {'cpgp': -1.0}
# vPG3                                            {'cpg3': -1.0}
# vpg2                                            {'cpg2': -1.0}
# vPEP                                            {'cpep': -1.0}
# vRibu5p                                      {'cribu5p': -1.0}
# vRIB5P                                        {'crib5p': -1.0}
# vXYL5P                                        {'cxyl5p': -1.0}
# vSED7P                                        {'csed7p': -1.0}
# vpyr                                            {'cpyr': -1.0}
# vPG                                              {'cpg': -1.0}
# vE4P                                            {'ce4p': -1.0}
# vGLP                                            {'cg1p': -1.0}
# vEXTER                                         {'cglcex': 1.0}
#
#                                                            law  reversible  \
# id
# vPTS         extracellular * rmaxPTS * cglcex * (cpep / cpy...       False
# vPGI         cytosol * rmaxPGI * (cg6p - cf6p / KPGIeq) / (...        True
# vPGM         cytosol * rmaxPGM * (cg6p - cg1p / KPGMeq) / (...        True
# vG6PDH       cytosol * rmaxG6PDH * cg6p * cnadp / ((cg6p + ...       False
# vPFK         cytosol * rmaxPFK * catp * cf6p / ((catp + KPF...       False
# vTA          cytosol * rmaxTA * (cgap * csed7p - ce4p * cf6...        True
# vTKA         cytosol * rmaxTKa * (crib5p * cxyl5p - csed7p ...        True
# vTKB         cytosol * rmaxTKb * (cxyl5p * ce4p - cf6p * cg...        True
# vMURSyNTH                               cytosol * rmaxMurSynth       False
# vALDO        cytosol * rmaxALDO * (cfdp - cgap * cdhap / kA...        True
# vGAPDH       cytosol * rmaxGAPDH * (cgap * cnad - cpgp * cn...        True
# vTIS         cytosol * rmaxTIS * (cdhap - cgap / kTISeq) / ...        True
# vTRPSYNTH                               cytosol * rmaxTrpSynth       False
# vG3PDH       cytosol * rmaxG3PDH * cdhap / (KG3PDHdhap + cd...       False
# vPGK         cytosol * rmaxPGK * (cadp * cpgp - catp * cpg3...        True
# vsersynth    cytosol * rmaxSerSynth * cpg3 / (KSerSynthpg3 ...       False
# vrpGluMu     cytosol * rmaxPGluMu * (cpg3 - cpg2 / KPGluMue...        True
# vENO         cytosol * rmaxENO * (cpg2 - cpep / KENOeq) / (...        True
# vPK          cytosol * rmaxPK * cpep * pow(cpep / KPKpep + ...       False
# vpepCxylase  cytosol * rmaxpepCxylase * cpep * (1 + pow(cfd...       False
# vSynth1      cytosol * rmaxSynth1 * cpep / (KSynth1pep + cpep)       False
# vSynth2      cytosol * rmaxSynth2 * cpyr / (KSynth2pyr + cpyr)       False
# vDAHPS       cytosol * rmaxDAHPS * pow(ce4p, nDAHPSe4p) * p...       False
# vPDH         cytosol * rmaxPDH * pow(cpyr, nPDH) / (KPDHpyr...       False
# vMethSynth                              cytosol * rmaxMetSynth       False
# vPGDH        cytosol * rmaxPGDH * cpg * cnadp / ((cpg + KPG...       False
# vR5PI        cytosol * rmaxR5PI * (cribu5p - crib5p / KR5PIeq)        True
# vRu5P        cytosol * rmaxRu5P * (cribu5p - cxyl5p / KRu5Peq)        True
# vPPK         cytosol * rmaxRPPK * crib5p / (KRPPKrib5p + cr...       False
# vG1PAT       cytosol * rmaxG1PAT * cg1p * catp * (1 + pow(c...       False
# vG6P                                      cytosol * Dil * cg6p       False
# vf6P                                      cytosol * Dil * cf6p       False
# vfdP                                      cytosol * Dil * cfdp       False
# vGAP                                      cytosol * Dil * cgap       False
# vDHAP                                    cytosol * Dil * cdhap       False
# vPGP                                      cytosol * Dil * cpgp       False
# vPG3                                      cytosol * Dil * cpg3       False
# vpg2                                      cytosol * Dil * cpg2       False
# vPEP                                      cytosol * Dil * cpep       False
# vRibu5p                                cytosol * Dil * cribu5p       False
# vRIB5P                                  cytosol * Dil * crib5p       False
# vXYL5P                                  cytosol * Dil * cxyl5p       False
# vSED7P                                  cytosol * Dil * csed7p       False
# vpyr                                      cytosol * Dil * cpyr       False
# vPG                                        cytosol * Dil * cpg       False
# vE4P                                      cytosol * Dil * ce4p       False
# vGLP                                      cytosol * Dil * cg1p       False
# vEXTER                  extracellular * Dil * (cfeed - cglcex)       False
#
#                                                     parameters modifiers
# id
# vPTS         {'rmaxPTS': 7829.78, 'KPTSa1': 3082.3, 'KPTSa2...        []
# vPGI         {'rmaxPGI': 650.9878687, 'KPGIeq': 0.1725, 'KP...     [cpg]
# vPGM         {'rmaxPGM': 0.8398242773, 'KPGMeq': 0.196, 'KP...        []
# vG6PDH       {'rmaxG6PDH': 1.380196955, 'KG6PDHg6p': 14.4, ...        []
# vPFK         {'rmaxPFK': 1840.584747, 'KPFKatps': 0.123, 'K...    [cpep]
# vTA                     {'rmaxTA': 10.87164108, 'KTAeq': 1.05}        []
# vTKA                   {'rmaxTKa': 9.473384783, 'KTKaeq': 1.2}        []
# vTKB                  {'rmaxTKb': 86.55855855, 'KTKbeq': 10.0}        []
# vMURSyNTH                         {'rmaxMurSynth': 0.00043711}        []
# vALDO        {'rmaxALDO': 17.41464425, 'kALDOeq': 0.144, 'k...        []
# vGAPDH       {'rmaxGAPDH': 921.5942861, 'KGAPDHeq': 0.63, '...        []
# vTIS         {'rmaxTIS': 68.67474392, 'kTISeq': 1.39, 'kTIS...        []
# vTRPSYNTH                           {'rmaxTrpSynth': 0.001037}        []
# vG3PDH         {'rmaxG3PDH': 0.01162042696, 'KG3PDHdhap': 1.0}        []
# vPGK         {'rmaxPGK': 3021.773771, 'KPGKeq': 1934.4, 'KP...        []
# vsersynth    {'rmaxSerSynth': 0.025712107, 'KSerSynthpg3': ...        []
# vrpGluMu     {'rmaxPGluMu': 89.04965407, 'KPGluMueq': 0.188...        []
# vENO         {'rmaxENO': 330.4476151, 'KENOeq': 6.73, 'KENO...        []
# vPK          {'rmaxPK': 0.06113150238, 'KPKpep': 0.31, 'nPK...    [cfdp]
# vpepCxylase  {'rmaxpepCxylase': 0.1070205858, 'KpepCxylasef...    [cfdp]
# vSynth1       {'rmaxSynth1': 0.01953897003, 'KSynth1pep': 1.0}        []
# vSynth2       {'rmaxSynth2': 0.07361855055, 'KSynth2pyr': 1.0}        []
# vDAHPS       {'rmaxDAHPS': 0.1079531227, 'nDAHPSe4p': 2.6, ...        []
# vPDH         {'rmaxPDH': 6.059531017, 'nPDH': 3.68, 'KPDHpy...        []
# vMethSynth                         {'rmaxMetSynth': 0.0022627}        []
# vPGDH        {'rmaxPGDH': 16.23235977, 'KPGDHpg': 37.5, 'KP...        []
# vR5PI                 {'rmaxR5PI': 4.83841193, 'KR5PIeq': 4.0}        []
# vRu5P                {'rmaxRu5P': 6.739029475, 'KRu5Peq': 1.4}        []
# vPPK            {'rmaxRPPK': 0.01290045226, 'KRPPKrib5p': 0.1}        []
# vG1PAT       {'rmaxG1PAT': 0.007525458026, 'KG1PATfdp': 0.1...    [cfdp]
# vG6P                                                        {}        []
# vf6P                                                        {}        []
# vfdP                                                        {}        []
# vGAP                                                        {}        []
# vDHAP                                                       {}        []
# vPGP                                                        {}        []
# vPG3                                                        {}        []
# vpg2                                                        {}        []
# vPEP                                                        {}        []
# vRibu5p                                                     {}        []
# vRIB5P                                                      {}        []
# vXYL5P                                                      {}        []
# vSED7P                                                      {}        []
# vpyr                                                        {}        []
# vPG                                                         {}        []
# vE4P                                                        {}        []
# vGLP                                                        {}        []
# vEXTER                                       {'cfeed': 110.96}        []

# %%
model.find('vpg')
# Out:
#                  name   stoichiometry                   law  reversible  \
# id
# vpg2  PG2 degradation  {'cpg2': -1.0}  cytosol * Dil * cpg2       False
#
#      parameters modifiers
# id
# vpg2         {}        []

# %% [markdown]
# You may access each reaction programmatically:

# %%
model.reactions.vPTS.products
# Out:
# ['cg6p', 'cpyr']

# %%
model.reactions.vPTS.parameters
# Out:
# OrderedDict([('rmaxPTS', 7829.78),
#              ('KPTSa1', 3082.3),
#              ('KPTSa2', 0.01),
#              ('KPTSa3', 245.3),
#              ('nPTSg6p', 3.66),
#              ('KPTSg6p', 2.15)])

# %%
model.reactions.vPTS.law
# Out:
# 'extracellular * rmaxPTS * cglcex * (cpep / cpyr) / ((KPTSa1 + KPTSa2 * (cpep / cpyr) + KPTSa3 * cglcex + cglcex * (cpep / cpyr)) * (1 + pow(cg6p, nPTSg6p) / KPTSg6p))'

# %% [markdown]
# Computes the reaction rate with the default parameters and concentrations, or by passing substrates concentrations and/or parameter values

# %%
model.reactions.vPTS.calculate_rate()
# Out:
# 6.238284215661543

# %% [markdown]
# List/find all or a set of prameters by pattern

# %%
model.find_parameters()
# Out:
#                     Value
# Parameter
# extracellular      65.000
# cytosol             1.000
# catp                4.270
# cadp                0.595
# camp                0.955
# ...                   ...
# vG1PAT_KG1PATfdp    0.119
# vG1PAT_nG1PATfdp    1.200
# vG1PAT_KG1PATatp    4.420
# vG1PAT_KG1PATg1p    3.200
# vEXTER_cfeed      110.960
#
# [127 rows x 1 columns]

# %% [markdown]
# # Kinetic Simulations

# %%
from mewpy.simulation.kinetic import KineticSimulation

# %%
sim = KineticSimulation(model)

# %% [markdown]
# You may define options for all simulations
# - *parameters*, a dictionary of parameter values
# - *t_points*, the integration time points `[1,2,3,4,5]` or time span (a list of two values `[start,end]`)
# - *timeout*, the solver timeout in seconds. If `timeout=0`, no timeout is applied
#
# When a time span is defined, it is divided into n time steps.
# The number of time steps is configurable:

# %%
from mewpy.solvers import SolverConfigurations
n = SolverConfigurations.N_STEPS
print('n = ',n)
# change the number of time steps
SolverConfigurations.N_STEPS =30
# Out:
# n =  20

# %% [markdown]
# You may change the *t_points* for all simulations:

# %%
sim.set_time(0,600,20)

# %% [markdown]
# or when running a simulation:

# %%
t_points = range(0,600,20)
res = sim.simulate(t_points=t_points)

# %% [markdown]
# When running a simulation you may also define:
# - *parameters*, a dictionary of parameters to be used in the simulation;
# - *initcon*, a vector of initial concentrations. The order is the same as the metabolites order;
# - *factors*, a dictionary of factores to be applied to parameters.

# %% [markdown]
# List the steady-state values

# %%
res.find()

# %% [markdown]
# Getting or viewing individual fluxes by id or pattern

# %%
print(res.fluxes['vPTS'])
# or
res.find('vPTS')

# %% [markdown]
# You may plot the changes on metabolite concentrations:

# %%
res.plot('cgap')

# %%
res.plot(['cglcex','cpyr'])

# %%
res.plot(size=(10,8))

# %%
res.get_y('cglcex')

# %%
import pandas as pd
pd.DataFrame(res.get_y('cglcex'),columns=['Concentration'],index=res.t)
